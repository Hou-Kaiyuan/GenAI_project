# %%
import pandas as pd

# %% [markdown]
# # GPT

# %% [markdown]
# ## gpt4_finetuned_2d_mode1_cut

# %%
results_pth='./gpt4_finetuned_2d_mode1_cut.csv'
gpt4_finetuned_2d_mode1_cut=pd.read_csv(results_pth)
gpt4_finetuned_2d_mode1_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      J
# 1           A  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      Y
# 2           A  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      A
# 3           A  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      F
# 4           A  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      U
# ..        ...                                                ...    ...
# 260         Z  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      L
# 261         Z  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      B
# 262         Z  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      M
# 263         Z  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      M
# 264         Z  <_io.TextIOWrapper name='./gpt4_finetuned_2d/2...      N
#
#                                       generated_answer
# ...

# %%
accuracy = (gpt4_finetuned_2d_mode1_cut['letter_gt'] == gpt4_finetuned_2d_mode1_cut['result']).mean() * 100

print(f"gpt4_finetuned_2d_mode1_test_cut Accuracy: {accuracy:.2f}%")
# Out:
# gpt4_finetuned_2d_mode1_test_cut Accuracy: 4.15%

# %% [markdown]
# ## gpt4_finetuned_2d_mode1_cut

# %%
results_pth='./gpt4_finetuned_2d_mode1_test_cut.csv'
gpt4_finetuned_2d_mode1_test_cut=pd.read_csv(results_pth)
gpt4_finetuned_2d_mode1_test_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./gpt4_finetuned_2d/2d/mode1_test_cut/A/_20241...      Q
# 1           A  ./gpt4_finetuned_2d/2d/mode1_test_cut/A/_20241...      Y
# 2           A  ./gpt4_finetuned_2d/2d/mode1_test_cut/A/_20241...      V
# 3           A  ./gpt4_finetuned_2d/2d/mode1_test_cut/A/_20241...      M
# 4           A  ./gpt4_finetuned_2d/2d/mode1_test_cut/A/_20241...      F
# ..        ...                                                ...    ...
# 258         Z  ./gpt4_finetuned_2d/2d/mode1_test_cut/Z/_20241...      X
# 259         Z  ./gpt4_finetuned_2d/2d/mode1_test_cut/Z/_20241...      S
# 260         Z  ./gpt4_finetuned_2d/2d/mode1_test_cut/Z/_20241...      H
# 261         Z  ./gpt4_finetuned_2d/2d/mode1_test_cut/Z/_20241...      J
# 262         Z  ./gpt4_finetuned_2d/2d/mode1_test_cut/Z/_20241...      T
#
#                                       generated_answer
# ...

# %%
accuracy = (gpt4_finetuned_2d_mode1_test_cut['letter_gt'] == gpt4_finetuned_2d_mode1_test_cut['result']).mean() * 100

print(f"gpt4_finetuned_2d_mode1_test_cut Accuracy: {accuracy:.2f}%")
# Out:
# gpt4_finetuned_2d_mode1_test_cut Accuracy: 6.08%

# %% [markdown]
# ## gpt4_pretrained_2d_mode1_cut

# %%
results_pth='./gpt4_pretrained_2d_mode1_cut.csv'
gpt4_pretrained_2d_mode1_cut=pd.read_csv(results_pth)
gpt4_pretrained_2d_mode1_cut
# Out:
#     letter_gt                                          file_name   result  \
# 0           A  ./gpt4_pretrained_2d/2d/mode1_cut/A/_202411181...     S, Z
# 1           A  ./gpt4_pretrained_2d/2d/mode1_cut/A/_202411181...        P
# 2           A  ./gpt4_pretrained_2d/2d/mode1_cut/A/_202411181...        S
# 3           A  ./gpt4_pretrained_2d/2d/mode1_cut/A/_202411181...        B
# 4           A  ./gpt4_pretrained_2d/2d/mode1_cut/A/_202411181...     M, W
# ..        ...                                                ...      ...
# 260         Z  ./gpt4_pretrained_2d/2d/mode1_cut/Z/_202411261...  B, P, R
# 261         Z  ./gpt4_pretrained_2d/2d/mode1_cut/Z/_202411261...        R
# 262         Z  ./gpt4_pretrained_2d/2d/mode1_cut/Z/_202411261...        O
# 263         Z  ./gpt4_pretrained_2d/2d/mode1_cut/Z/_202411261...        R
# 264         Z  ./gpt4_pretrained_2d/2d/mode1_cut/Z/_202411261...        S
#
#                                       generated_answer
# ...

# %%
accuracy = (gpt4_pretrained_2d_mode1_cut['letter_gt'] == gpt4_pretrained_2d_mode1_cut['result']).mean() * 100

print(f"gpt4_pretrained_2d_mode1_cut Accuracy: {accuracy:.2f}%")
# Out:
# gpt4_pretrained_2d_mode1_cut Accuracy: 4.91%

# %% [markdown]
# ## gpt4_pretrained_2d_mode1_test_cut

# %%
results_pth='./gpt4_pretrained_2d_mode1_test_cut.csv'
gpt4_pretrained_2d_mode1_test_cut=pd.read_csv(results_pth)
gpt4_pretrained_2d_mode1_test_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./gpt4_pretrained_2d/2d/mode1_test_cut/A/_2024...      S
# 1           A  ./gpt4_pretrained_2d/2d/mode1_test_cut/A/_2024...      W
# 2           A  ./gpt4_pretrained_2d/2d/mode1_test_cut/A/_2024...      S
# 3           A  ./gpt4_pretrained_2d/2d/mode1_test_cut/A/_2024...      S
# 4           A  ./gpt4_pretrained_2d/2d/mode1_test_cut/A/_2024...      M
# ..        ...                                                ...    ...
# 258         Z  ./gpt4_pretrained_2d/2d/mode1_test_cut/Z/_2024...      M
# 259         Z  ./gpt4_pretrained_2d/2d/mode1_test_cut/Z/_2024...      S
# 260         Z  ./gpt4_pretrained_2d/2d/mode1_test_cut/Z/_2024...      E
# 261         Z  ./gpt4_pretrained_2d/2d/mode1_test_cut/Z/_2024...      M
# 262         Z  ./gpt4_pretrained_2d/2d/mode1_test_cut/Z/_2024...      L
#
#                                       generated_answer
# ...

# %%
accuracy = (gpt4_pretrained_2d_mode1_test_cut['letter_gt'] == gpt4_pretrained_2d_mode1_test_cut['result']).mean() * 100

print(f"gpt4_pretrained_2d_mode1_test_cut Accuracy: {accuracy:.2f}%")
# Out:
# gpt4_pretrained_2d_mode1_test_cut Accuracy: 3.42%

# %% [markdown]
# ## llama8b_pretrained_2d_mode1_test_cut

# %%
results_pth='./llama8b_pretrained_2d_mode1_test_cut.csv'
llama8b_pretrained_2d_mode1_test_cut=pd.read_csv(results_pth)
llama8b_pretrained_2d_mode1_test_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./llama8b_pretrained_2d/2d/mode1_test_cut/A/_2...    NaN
# 1           A  ./llama8b_pretrained_2d/2d/mode1_test_cut/A/_2...  None.
# 2           A  ./llama8b_pretrained_2d/2d/mode1_test_cut/A/_2...    NaN
# 3           A  ./llama8b_pretrained_2d/2d/mode1_test_cut/A/_2...  None.
# 4           A  ./llama8b_pretrained_2d/2d/mode1_test_cut/A/_2...  None.
# ..        ...                                                ...    ...
# 258         Z  ./llama8b_pretrained_2d/2d/mode1_test_cut/Z/_2...    NaN
# 259         Z  ./llama8b_pretrained_2d/2d/mode1_test_cut/Z/_2...    NaN
# 260         Z  ./llama8b_pretrained_2d/2d/mode1_test_cut/Z/_2...    NaN
# 261         Z  ./llama8b_pretrained_2d/2d/mode1_test_cut/Z/_2...  None.
# 262         Z  ./llama8b_pretrained_2d/2d/mode1_test_cut/Z/_2...  None.
#
#                                       generated_answer
# ...

# %%
accuracy = (llama8b_pretrained_2d_mode1_test_cut['letter_gt'] == llama8b_pretrained_2d_mode1_test_cut['result']).mean() * 100

print(f"llama8b_pretrained_2d_mode1_test_cut Accuracy: {accuracy:.2f}%")
# Out:
# llama8b_pretrained_2d_mode1_test_cut Accuracy: 0.00%

# %% [markdown]
# ## llama8b_finetuned_2d_mode1_cut

# %%
results_pth='./llama8b_finetuned_2d_mode1_cut.csv'
llama8b_finetuned_2d_mode1_cut=pd.read_csv(results_pth)
llama8b_finetuned_2d_mode1_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./llama8b_finetuned_2d/2d/mode1_cut/A/_2024111...      K
# 1           A  ./llama8b_finetuned_2d/2d/mode1_cut/A/_2024111...      H
# 2           A  ./llama8b_finetuned_2d/2d/mode1_cut/A/_2024111...      K
# 3           A  ./llama8b_finetuned_2d/2d/mode1_cut/A/_2024111...      H
# 4           A  ./llama8b_finetuned_2d/2d/mode1_cut/A/_2024111...      H
# ..        ...                                                ...    ...
# 260         Z  ./llama8b_finetuned_2d/2d/mode1_cut/Z/_2024112...      T
# 261         Z  ./llama8b_finetuned_2d/2d/mode1_cut/Z/_2024112...      S
# 262         Z  ./llama8b_finetuned_2d/2d/mode1_cut/Z/_2024112...      S
# 263         Z  ./llama8b_finetuned_2d/2d/mode1_cut/Z/_2024112...      H
# 264         Z  ./llama8b_finetuned_2d/2d/mode1_cut/Z/_2024112...      M
#
#                                       generated_answer
# ...

# %%
accuracy = (llama8b_finetuned_2d_mode1_cut['letter_gt'] == llama8b_finetuned_2d_mode1_cut['result']).mean() * 100

print(f"llama8b_finetuned_2d_mode1_cut Accuracy: {accuracy:.2f}%")
# Out:
# llama8b_finetuned_2d_mode1_cut Accuracy: 3.77%

# %% [markdown]
# ## llama8b_finetuned_2d_mode1_test_cut

# %%
results_pth='./llama8b_finetuned_2d_mode1_test_cut.csv'
llama8b_finetuned_2d_mode1_test_cut=pd.read_csv(results_pth)
llama8b_finetuned_2d_mode1_test_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./llama8b_finetuned_2d/2d/mode1_test_cut/A/_20...      E
# 1           A  ./llama8b_finetuned_2d/2d/mode1_test_cut/A/_20...      K
# 2           A  ./llama8b_finetuned_2d/2d/mode1_test_cut/A/_20...      L
# 3           A  ./llama8b_finetuned_2d/2d/mode1_test_cut/A/_20...      H
# 4           A  ./llama8b_finetuned_2d/2d/mode1_test_cut/A/_20...      T
# ..        ...                                                ...    ...
# 258         Z  ./llama8b_finetuned_2d/2d/mode1_test_cut/Z/_20...      M
# 259         Z  ./llama8b_finetuned_2d/2d/mode1_test_cut/Z/_20...      J
# 260         Z  ./llama8b_finetuned_2d/2d/mode1_test_cut/Z/_20...      J
# 261         Z  ./llama8b_finetuned_2d/2d/mode1_test_cut/Z/_20...      K
# 262         Z  ./llama8b_finetuned_2d/2d/mode1_test_cut/Z/_20...      D
#
#                                       generated_answer
# ...

# %%
accuracy = (llama8b_finetuned_2d_mode1_test_cut['letter_gt'] == llama8b_finetuned_2d_mode1_test_cut['result']).mean() * 100

print(f"llama8b_finetuned_2d_mode1_test_cut Accuracy: {accuracy:.2f}%")
# Out:
# llama8b_finetuned_2d_mode1_test_cut Accuracy: 3.42%

# %% [markdown]
# # gpt4_pretrained_2d_fewshot_mode1_test_cut

# %%
results_pth='./gpt4_pretrained_2d_fewshot_mode1_test_cut.csv'
gpt4_pretrained_2d_fewshot_mode1_test_cut=pd.read_csv(results_pth)
gpt4_pretrained_2d_fewshot_mode1_test_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      A
# 1           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
# 2           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      A
# 3           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      J
# 4           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
# ..        ...                                                ...    ...
# 258         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
# 259         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
# 260         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
# 261         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
# 262         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_test_cut...      Z
#
#                                       generated_answer
# ...

# %%
accuracy = (gpt4_pretrained_2d_fewshot_mode1_test_cut['letter_gt'] == gpt4_pretrained_2d_fewshot_mode1_test_cut['result']).mean() * 100

print(f"gpt4_pretrained_2d_fewshot_mode1_test_cut Accuracy: {accuracy:.2f}%")
# Out:
# gpt4_pretrained_2d_fewshot_mode1_test_cut Accuracy: 58.17%

# %% [markdown]
# # gpt4_pretrained_2d_fewshot_mode1_cut

# %%
results_pth='./gpt4_pretrained_2d_fewshot_mode1_cut.csv'
gpt4_pretrained_2d_fewshot_mode1_cut=pd.read_csv(results_pth)
gpt4_pretrained_2d_fewshot_mode1_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/A/_2...      N
# 1           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/A/_2...      A
# 2           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/A/_2...      A
# 3           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/A/_2...      Z
# 4           A  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/A/_2...      C
# ..        ...                                                ...    ...
# 281         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/Z/_2...      Z
# 282         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/Z/_2...      Z
# 283         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/Z/_2...      Z
# 284         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/Z/_2...      Z
# 285         Z  ./gpt4_pretrained_2d_fewshot/2d/mode1_cut/Z/_2...      Z
#
#                                       generated_answer
# ...

# %%
accuracy = (gpt4_pretrained_2d_fewshot_mode1_cut['letter_gt'] == gpt4_pretrained_2d_fewshot_mode1_cut['result']).mean() * 100

print(f"gpt4_pretrained_2d_fewshot_mode1_cut Accuracy: {accuracy:.2f}%")
# Out:
# gpt4_pretrained_2d_fewshot_mode1_cut Accuracy: 85.66%

# %% [markdown]
# # llama8b_ft_2d_fewshot_mode1_cut

# %%
results_pth='./llama8b_ft_2d_fewshot_mode1_cut.csv'
llama8b_ft_2d_fewshot_mode1_cut=pd.read_csv(results_pth)

# %%
accuracy = (llama8b_ft_2d_fewshot_mode1_cut['letter_gt'] == llama8b_ft_2d_fewshot_mode1_cut['result']).mean() * 100

print(f"llama8b_ft_2d_fewshot_mode1_cut Accuracy: {accuracy:.2f}%")
# Out:
# llama8b_ft_2d_fewshot_mode1_cut Accuracy: 79.31%

# %% [markdown]
# # llama8b_pretrained_2d_fewshot_mode1_cut

# %%
results_pth='./llama8b_pretrained_2d_fewshot_mode1_cut.csv'
llama8b_pretrained_2d_fewshot_mode1_cut=pd.read_csv(results_pth)
# llama8b_pretrained_2d_fewshot_mode1_cut=llama8b_pretrained_2d_fewshot_mode1_cut.drop_duplicates()
llama8b_pretrained_2d_fewshot_mode1_cut
# Out:
#     letter_gt                                          file_name result  \
# 0           A  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/A...    NaN
# 1           A  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/A...    NaN
# 2           A  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/A...    NaN
# 3           A  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/A...    NaN
# 4           A  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/A...    NaN
# ..        ...                                                ...    ...
# 170         P  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/P...    NaN
# 171         P  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/P...    NaN
# 172         P  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/P...    NaN
# 173         P  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/P...    NaN
# 174         P  ./llama8b_pretrained_2d_fewshot/2d/mode1_cut/P...    NaN
#
#                                       generated_answer
# ...

# %%
accuracy = (llama8b_pretrained_2d_fewshot_mode1_cut['letter_gt'] == llama8b_pretrained_2d_fewshot_mode1_cut['result']).mean() * 100

print(f"llama8b_pretrained_2d_fewshot_mode1_cut Accuracy: {accuracy:.2f}%")
# Out:
# llama8b_pretrained_2d_fewshot_mode1_cut Accuracy: 0.00%
